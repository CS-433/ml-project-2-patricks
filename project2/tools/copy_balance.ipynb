# %%
# get file list
import os
import pickle
path = '/Users/elenath/ALEX/EPFL/Courses/Machine Learning/Project/p2_data/data/classification_dataset_balanced/train/defects'
files = os.listdir(path)
copyfiles = []
for file in files:
    if 'copy' in file:
        copyfiles.append(file)
with open('file.pkl', 'wb') as f:
    pickle.dump(copyfiles, f)

# %%
path = ""
with open('file.pkl', 'rb') as f:
    copyfiles = pickle.load(f)
for file in copyfiles:
    origin_file = "_".join(file.split('_')[:-1])+'.png'
    copy_num = file.split('_')[-1]
    print(origin_file)
# Out:
# image_0001273_crop_0000004.png
# image_0001152_crop_0000002.png
# image_0000461_crop_0000004.png
# image_0000448_crop_0000001.png
# image_0001407_crop_0000006.png
# image_0001075_crop_0000005.png
# image_0000587_crop_0000002.png
# image_0001497_crop_0000010.png
# image_0000481_crop_0000002.png
# image_0001421_crop_0000012.png
# image_0000042_crop_0000001.png
# image_0000583_crop_0000007.png
# image_0000613_crop_0000001.png
# image_0000584_crop_0000005.png
# image_0001564_crop_0000009.png
# image_0001473_crop_0000002.png
# image_0000398_crop_0000003.png
# image_0001484_crop_0000001.png
# image_0000705_crop_0000006.png
# image_0000525_crop_0000002.png
# image_0001533_crop_0000001.png
# image_0001260_crop_0000004.png
# image_0000753_crop_0000002.png
# image_0001131_crop_0000003.png
# image_0001249_crop_0000010.png
# image_0001187_crop_0000001.png
# image_0000709_crop_0000001.png
# image_0000981_crop_0000008.png
# image_0000476_crop_0000001.png
# image_0001145_crop_0000007.png
# ...
