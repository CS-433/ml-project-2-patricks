# %%
from torchvision import transforms
from PIL import Image

# %%
data_path = '/Users/elenath/ALEX/EPFL/Courses/Machine Learning/Project/p2_data/data/classification_dataset_balanced/train/defects/'
image = 'image_0000028_crop_0000001.png'
img = Image.open(data_path+image)

data_transforms1 = transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomCrop(224)
        ])
data_transforms2 = transforms.Compose([
        transforms.Resize((224,224))
        ])

# %%
img_trans = data_transforms1(img)
img_trans
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FE70D7F8510>

# %%
img_trans = data_transforms2(img)
img_trans
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FE6EEBF4710>
